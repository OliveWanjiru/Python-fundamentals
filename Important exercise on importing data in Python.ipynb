# %%
import pandas as pd

# %%
location_data =pd.read_csv("C:/Users/user/Downloads/Lending-company.csv", usecols = ['StringID', 'Location', 'Region'], index_col = 'StringID')
location_data.head()
# Out:
#              Location    Region
# StringID
# LoanID_1   Location 3  Region 2
# LoanID_2   Location 6  Region 6
# LoanID_3   Location 8  Region 3
# LoanID_4  Location 26  Region 2
# LoanID_5  Location 34  Region 3

# %%
filename = "C:/Users/user/Downloads/Lending-company-single-column-data.csv"
my_csv_data =pd.read_csv(filename)
my_csv_data.head()
# Out:
#   LoanID,StringID,Product,CustomerGender,Location,Region,TotalPrice,StartDate,Deposit,DailyRate,TotalDaysYr,AmtPaid36,AmtPaid60,AmtPaid360,LoanStatus
# 0  1,LoanID_1,Product B,Female,Location 3,Region ...
# 1  2,LoanID_2,Product D,Female,Location 6,Region ...
# 2  3,LoanID_3,Product B,Male,Location 8,Region 3,...
# 3  4,LoanID_4,Product A,Male,Location 26,Region 2...
# 4  5,LoanID_5,Product B,Female,Location 34,Region...

# %% [markdown]
# Seeing as we went with the default parser and it has delivered a suboptimal result we need to help it a little bit we choose the sep argument with the value of '\,' we need the backslash beacuse we've been dealing with the raw string otherwise a comma between single quotes would suffice then you must specify that you want to use the python engine otherwiser you will get an error message warning you that a python engine will be used

# %%
filename = "C:/Users/user/Downloads/Lending-company-single-column-data.csv"
my_csv_data =pd.read_csv(filename,sep ='\\,')
my_csv_data.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13548\3617315094.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   my_csv_data =pd.read_csv(filename,sep ='\\,')
#   "LoanID  StringID    Product CustomerGender     Location    Region  \
# 0      "1  LoanID_1  Product B         Female   Location 3  Region 2
# 1      "2  LoanID_2  Product D         Female   Location 6  Region 6
# 2      "3  LoanID_3  Product B           Male   Location 8  Region 3
# 3      "4  LoanID_4  Product A           Male  Location 26  Region 2
# 4      "5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# ...

# %%
filename = "C:/Users/user/Downloads/Lending-company-single-column-data.csv"
my_csv_data =pd.read_csv(filename, sep = '\\,', engine = 'python')
my_csv_data.head()
# Out:
#   "LoanID  StringID    Product CustomerGender     Location    Region  \
# 0      "1  LoanID_1  Product B         Female   Location 3  Region 2
# 1      "2  LoanID_2  Product D         Female   Location 6  Region 6
# 2      "3  LoanID_3  Product B           Male   Location 8  Region 3
# 3      "4  LoanID_4  Product A           Male  Location 26  Region 2
# 4      "5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus"
# 0       4166       14621     Active"
# 1       4096       16041     Active"
# ...

# %% [markdown]
# Our only issue now is that every row has been treated as a string the quotes athe beginning and end of each row indicate this

# %%
filename = "C:/Users/user/Downloads/Lending-company-single-column-data.csv"
my_csv_data =pd.read_csv(filename, delimiter = '\\,', engine = 'python')
my_csv_data.head()
# Out:
#   "LoanID  StringID    Product CustomerGender     Location    Region  \
# 0      "1  LoanID_1  Product B         Female   Location 3  Region 2
# 1      "2  LoanID_2  Product D         Female   Location 6  Region 6
# 2      "3  LoanID_3  Product B           Male   Location 8  Region 3
# 3      "4  LoanID_4  Product A           Male  Location 26  Region 2
# 4      "5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus"
# 0       4166       14621     Active"
# 1       4096       16041     Active"
# ...

# %% [markdown]
# As we can see both delimiter and sep arguments are treated identically
